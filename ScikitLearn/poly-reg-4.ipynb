# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # Degree 3

# %%
# Generate synthetic non-linear data
np.random.seed(42)
X = np.linspace(-3, 3, 100).reshape(-1, 1)  # Feature
y = X**3 - 2*X - X - 2 + np.random.randn(100, 1) * 3  # Qubic relationship with noise

# Scatter plot of data
plt.scatter(X, y, label="Data")
plt.xlabel("Feature (X)")
plt.ylabel("Target (y)")
plt.title("Non-Linear Data")
plt.legend()
plt.show()

# %%
# Polynomial Regression (Degree 3)
poly_reg = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())
poly_reg.fit(X, y)

# Predictions
y_pred_poly = poly_reg.predict(X)
y2 = X**3 - 2*X - X - 2

# Polynomial Regression (Degree 5)
poly_reg_5 = make_pipeline(PolynomialFeatures(degree=5), LinearRegression())
poly_reg_5.fit(X, y)

# Predictions
y_pred_poly_5 = poly_reg_5.predict(X)

# Plot results
#plt.scatter(X, y, label="Data")

# Plot results
plt.scatter(X, y, label="Data")
plt.plot(X, y_pred_poly, color="red", label="Polynomial Fit (Degree 2)")
plt.plot(X, y2, color="green", label="Original Polynomial (Degree 2)")
plt.plot(X, y_pred_poly_5, color="purple", label="Polynomial Fit (Degree 5)")
plt.xlabel("Feature (X)")
plt.ylabel("Target (y)")
plt.title("Polynomial Regression (Degree 3)")
plt.legend()
plt.show()

# %%
# Polynomial Regression (Degree 5)
poly_reg_5 = make_pipeline(PolynomialFeatures(degree=5), LinearRegression())
poly_reg_5.fit(X, y)

# Predictions
y_pred_poly_5 = poly_reg_5.predict(X)

# Plot results
plt.scatter(X, y, label="Data")
plt.plot(X, y_pred_poly_5, color="purple", label="Polynomial Fit (Degree 5)")
plt.xlabel("Feature (X)")
plt.ylabel("Target (y)")
plt.title("Polynomial Regression (Degree 5)")
plt.legend()
plt.show()
